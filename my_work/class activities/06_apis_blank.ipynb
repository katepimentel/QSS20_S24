# %%
## imports
import pandas as pd
import numpy as np
import re
import requests
import yaml


## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # 1. Example 1: no credentials; no wrapper
#
# Site: National Assessment of Education Progress (NAEP)
#
# Documentation: https://www.nationsreportcard.gov/api_documentation.aspx
#
# Base link: https://www.nationsreportcard.gov/DataService/GetAdhocData.aspx

# %% [markdown]
# ## 1.1 Query to pull some data

# %%
## using their example query of 2011 writing scores separated by gender
## based on here - https://stackoverflow.com/questions/40836749/pythonic-way-of-writing-a-single-line-long-string
## using the ( ) syntax to formulate a long
## string without linebreaks added
example_naep_query = (
'https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade=8&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011')


example_naep_query
# Out:
# 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?type=data&subject=writing&grade=8&subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011'

# %%
## use requests to call the api
naep_resp = requests.get(example_naep_query)
naep_resp
print(type(naep_resp))

## get the json contents of the response 
## here, we're assuming valid response
naep_resp_j = naep_resp.json()
naep_resp_j

## with result, turn it into a dataframe
naep_resp_d = pd.DataFrame(naep_resp_j['result'])
naep_resp_d
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# {'status': 200,
#  'result': [{'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 2,
#    'CohortLabel': 'Grade 8',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 8,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Gender',
#    'varValue': '1',
#    'varValueLabel': 'Male',
#    'value': 139.099504632971,
#    'isStatDisplayable': 1,
#    'errorFlag': 0},
#   {'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 2,
#    'CohortLabel': 'Grade 8',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 8,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Gender',
#    'varValue': '2',
#    'varValueLabel': 'Female',
#    'value': 158.567104984955,
#    'isStatDisplayable': 1,
#    'errorFlag': 0}]}
#    year sample yearSampleLabel  Cohort CohortLabel stattype subject  grade  \
# 0  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 1  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
#
#    scale jurisdiction       jurisLabel variable variableLabel varValue  \
# 0  WRIRP           NP  National public   GENDER        Gender        1
# 1  WRIRP           NP  National public   GENDER        Gender        2
#
#   varValueLabel       value  isStatDisplayable  errorFlag
# 0          Male  139.099505                  1          0
# 1        Female  158.567105                  1          0

# %% [markdown]
# ## 1.2 What happens if there's an error in our query?

# %%
## here's a query that from the documentation we know
## won't work since i modified year to 2025 which doesnt
## exist in the data
wrong_naep_query = (
'https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade=8&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2025')

wrong_naep_query
# Out:
# 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?type=data&subject=writing&grade=8&subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2025'

# %%
## use requests to call the api
naep_wrong_resp = requests.get(wrong_naep_query)
naep_wrong_resp
# Out:
# <Response [200]>

# %%
dir(naep_wrong_resp)
naep_wrong_resp.content
# Out:
# ['__attrs__',
#  '__bool__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__enter__',
#  '__eq__',
#  '__exit__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__nonzero__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_content',
#  '_content_consumed',
#  '_next',
#  'apparent_encoding',
#  'close',
#  'connection',
#  'content',
#  'cookies',
#  'elapsed',
#  'encoding',
#  'headers',
#  'history',
#  'is_permanent_redirect',
#  'is_redirect',
#  'iter_content',
#  'iter_lines',
#  'json',
#  'links',
#  'next',
#  'ok',
#  'raise_for_status',
#  'raw',
#  'reason',
#  'request',
#  'status_code',
#  'text',
#  'url']
# b'{"status":400,"result": "System.Exception: The query \'SELECT DISTINCT Framework FROM Cycles WHERE Subject=\'WRI\' AND Cohort=2 AND CONVERT(VARCHAR(10),Year)+Sample IN (\'2025R3\')\' did not return exactly 1 framework. Make sure you can trend the years defined for the given subject and cohort.\r\n   at NRCDataService3.GetAdhocData.GetFramework(NDEContext& ndeContext, String subjectCode, List`1 yearSamples, String cohort) in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 2091\r\n   at NRCDataService3.GetAdhocData.PopulateBaseOrchestratorRequest() in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 1781\r\n   at NRCDataService3.GetAdhocData.ConstructRequest_Datapoint() in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 628\r\n   at NRCDataService3.GetAdhocData.Page_Load(Object sender, EventArgs e) in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 179"}'

# %%
## in the case of this particular api,
## the call returns some response but
## when we try to extract the json containing
## status or results, we get in an error
#naep_wrong_resp.json() # uncomment to see error

# %% [markdown]
# ### 1.2.2 More all-purpose way of allowing remainder of calls to run: try, except

# %%
## putting it in a try; except as general error catching
try:
    results = naep_wrong_resp.json()['result']
except Exception as e:
    print('Failed to get result from API due to error:')
    print(e) # or just: pass
# Out:
# Failed to get result from API due to error:
# Invalid control character at: line 1 column 289 (char 288)

# %% [markdown]
# ### 1.2.3 Can usually also find more targeted way but that varies more across APIs

# %%
## if we wanted do more specific error catching,
## see that the status == 400 actually appears here
## so could write if else along those lines
naep_wrong_resp.text
naep_resp.text

if "System.Exception" in naep_wrong_resp.text:
    print("NAEP results not found")
# Out:
# '{"status":400,"result": "System.Exception: The query \'SELECT DISTINCT Framework FROM Cycles WHERE Subject=\'WRI\' AND Cohort=2 AND CONVERT(VARCHAR(10),Year)+Sample IN (\'2025R3\')\' did not return exactly 1 framework. Make sure you can trend the years defined for the given subject and cohort.\r\n   at NRCDataService3.GetAdhocData.GetFramework(NDEContext& ndeContext, String subjectCode, List`1 yearSamples, String cohort) in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 2091\r\n   at NRCDataService3.GetAdhocData.PopulateBaseOrchestratorRequest() in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 1781\r\n   at NRCDataService3.GetAdhocData.ConstructRequest_Datapoint() in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 628\r\n   at NRCDataService3.GetAdhocData.Page_Load(Object sender, EventArgs e) in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 179"}'
# '{"status":200,"result": [{"year":2011,"sample":"R3","yearSampleLabel":"2011","Cohort":2,"CohortLabel":"Grade 8","stattype":"MN:MN","subject":"WRI","grade":8,"scale":"WRIRP","jurisdiction":"NP","jurisLabel":"National public","variable":"GENDER","variableLabel":"Gender","varValue":"1","varValueLabel":"Male","value":139.099504632971,"isStatDisplayable":1,"errorFlag":0},{"year":2011,"sample":"R3","yearSampleLabel":"2011","Cohort":2,"CohortLabel":"Grade 8","stattype":"MN:MN","subject":"WRI","grade":8,"scale":"WRIRP","jurisdiction":"NP","jurisLabel":"National public","variable":"GENDER","variableLabel":"Gender","varValue":"2","varValueLabel":"Female","value":158.567104984955,"isStatDisplayable":1,"errorFlag":0}]}'
# NAEP results not found

# %% [markdown]
# ## Activity 1: writing a function to make multiple, sequential calls
#
# - Say we want to pull the data for grades 4, 8, and 12
# - How can we write a function that iterates over a list of those grades and pulls the data for each grade?
#
# **Note**: an ideal function would have arguments for each parameter in the API like subject, subscale, etc. Here we can leave those other parts constant

# %%
"I am in the {} building. and I also go to {} for lunch".format("Silsby", "Collis")
# Out:
# 'I am in the Silsby building. and I also go to Collis for lunch'

# %%
activity_query = ('https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade={}&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011')

def pull_grades(query, grade):
    new_query = query.format(grade)
    try:
        # use requests to call the api
        naep_resp = requests.get(new_query)
        # get the json contents of the response
        naep_resp_j = naep_resp.json()
        # with result, turn it into a dataframe
        naep_resp_d = pd.DataFrame(naep_resp_j['result'])
        return naep_resp_d
    except Exception as e:
        return None
pull_grades(activity_query, 4)
pull_grades(activity_query, 8)
pull_grades(activity_query, 12)
# Out:
#    year sample yearSampleLabel  Cohort CohortLabel stattype subject  grade  \
# 0  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 1  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
#
#    scale jurisdiction       jurisLabel variable variableLabel varValue  \
# 0  WRIRP           NP  National public   GENDER        Gender        1
# 1  WRIRP           NP  National public   GENDER        Gender        2
#
#   varValueLabel       value  isStatDisplayable  errorFlag
# 0          Male  139.099505                  1          0
# 1        Female  158.567105                  1          0
#    year sample yearSampleLabel  Cohort CohortLabel stattype subject  grade  \
# 0  2011     R3            2011       3    Grade 12    MN:MN     WRI     12
# 1  2011     R3            2011       3    Grade 12    MN:MN     WRI     12
#
#    scale jurisdiction       jurisLabel variable variableLabel varValue  \
# 0  WRIRP           NP  National public   GENDER        Gender        1
# 1  WRIRP           NP  National public   GENDER        Gender        2
#
#   varValueLabel       value  isStatDisplayable  errorFlag
# 0          Male  141.256978                  1          0
# 1        Female  155.385917                  1          0

# %% [markdown]
# # 2. Example 2: needs credentials; no wrapper

# %% [markdown]
# Create an account here: https://www.yelp.com/developers/v3/manage_app

# %%
## get the key
API_KEY = "9a7z5JFCeZSZ9kY_ivUKIC1xZy7XgF6nYziSE_b50iYzuqX7fI6g161IzIqG_BgcoqLDp_YQBPDKvUrdtcS0Ho5iyKU1zqlBDK66TdruvRVzYVB73LxUwI7nSa0zZnYx"

# %%
## use documentation to define what to search
## doc: https://www.yelp.com/developers/documentation/v3/business_search
## write the query 
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"
my_location = "Hanover,NH,03755"
yelp_genquery = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location)

## use requests to call the API; here, we're
## passing it our credentials (structure varies
## by API and telling it to only return 10 results
## (max is 50 at once)
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp = requests.get(yelp_genquery, headers = header)
yelp_genresp

## then, look at structure of response
yelp_genjson = yelp_genresp.json()
# Out:
# <Response [200]>

# %%
## example business
yelp_genjson['businesses'][0]

## more automatic way of summarizing but things end up in lists
## within columns for things like categories
yelp_gendf = pd.DataFrame(yelp_genjson['businesses'])
yelp_gendf.head()
# Out:
# {'id': '8ybF6YyRldtZmU9jil4xlg',
#  'alias': 'mollys-restaurant-and-bar-hanover',
#  'name': "Molly's Restaurant & Bar",
#  'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/TJLrrA6z-SnPgZfrs2GQNQ/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/mollys-restaurant-and-bar-hanover?adjust_creative=jmRDz3dQUAD9n2fAUWwDPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jmRDz3dQUAD9n2fAUWwDPQ',
#  'review_count': 508,
#  'categories': [{'alias': 'tradamerican', 'title': 'American'},
#   {'alias': 'burgers', 'title': 'Burgers'},
#   {'alias': 'pizza', 'title': 'Pizza'}],
#  'rating': 3.9,
#  'coordinates': {'latitude': 43.701144, 'longitude': -72.2894249},
#  'transactions': ['delivery'],
#  'price': '$$',
#  'location': {'address1': '43 South Main St',
#   'address2': '',
#   'address3': '',
#   'city': 'Hanover',
#   'zip_code': '03755',
#   'country': 'US',
#   'state': 'NH',
#   'display_address': ['43 South Main St', 'Hanover, NH 03755']},
#  'phone': '+16036432570',
#  'display_phone': '(603) 643-2570',
#  'distance': 250.8301601841674,
#  'attributes': {'business_temp_closed': None,
#   'menu_url': 'http://www.mollysrestaurant.com/uploadcache/Mollys-Menu.pdf',
#   'open24_hours': None,
#   'waitlist_reservation': None}}
#                        id                               alias  \
# 0  8ybF6YyRldtZmU9jil4xlg   mollys-restaurant-and-bar-hanover
# 1  XVGEEIH5rVB2QzW-qywcJw              base-camp-cafe-hanover
# 2  5WW4g_LRwau29KyjZGLyAA            sawtooth-kitchen-hanover
# 3  qxm3VNmD0O2zw8m9U8SxZg                    duende-hanover-2
# 4  KA8yhrd-ClVYMyOefXdVYg  lous-restaurant-and-bakery-hanover
#
#                         name  \
# 0   Molly's Restaurant & Bar
# 1             Base Camp Cafe
# 2           Sawtooth Kitchen
# 3                     Duende
# 4  Lou's Restaurant & Bakery
#
#                                            image_url  is_closed  \
# 0  https://s3-media4.fl.yelpcdn.com/bphoto/TJLrrA...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/p8_YiE...      False
# 2  https://s3-media3.fl.yelpcdn.com/bphoto/61MNG4...      False
# 3  https://s3-media4.fl.yelpcdn.com/bphoto/rf_h2D...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/VAx8H9...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/mollys-restaurant-and...           508
# 1  https://www.yelp.com/biz/base-camp-cafe-hanove...           247
# 2  https://www.yelp.com/biz/sawtooth-kitchen-hano...            25
# 3  https://www.yelp.com/biz/duende-hanover-2?adju...            11
# 4  https://www.yelp.com/biz/lous-restaurant-and-b...           383
#
#                                           categories  rating  \
# 0  [{'alias': 'tradamerican', 'title': 'American'...     3.9
# 1  [{'alias': 'himalayan', 'title': 'Himalayan/Ne...     4.4
# 2  [{'alias': 'chickenshop', 'title': 'Chicken Sh...     4.1
# 3  [{'alias': 'spanish', 'title': 'Spanish'}, {'a...     3.8
# 4  [{'alias': 'tradamerican', 'title': 'American'...     4.2
#
#                                          coordinates transactions price  \
# 0  {'latitude': 43.701144, 'longitude': -72.2894249}   [delivery]    $$
# 1  {'latitude': 43.700626, 'longitude': -72.2887803}   [delivery]    $$
# 2    {'latitude': 43.70158, 'longitude': -72.289641}           []   NaN
# 3  {'latitude': 43.70074272457673, 'longitude': -...           []   NaN
# 4    {'latitude': 43.70143, 'longitude': -72.289001}   [delivery]    $$
#
#                                             location         phone  \
# 0  {'address1': '43 South Main St', 'address2': '...  +16036432570
# 1  {'address1': '3 Lebanon St', 'address2': 'Ste ...  +16036432007
# 2  {'address1': '33 S Main St', 'address2': '', '...  +16036435134
# 3  {'address1': '15 Lebanon St', 'address2': '', ...  +16033064826
# 4  {'address1': '30 S Main St', 'address2': '', '...  +16036433321
#
#     display_phone    distance  \
# 0  (603) 643-2570  250.830160
# 1  (603) 643-2007  196.139758
# 2  (603) 643-5134  242.607552
# 3  (603) 306-4826  107.388862
# 4  (603) 643-3321  244.006059
#
#                                           attributes
# 0  {'business_temp_closed': None, 'menu_url': 'ht...
# 1  {'business_temp_closed': None, 'menu_url': 'ht...
# 2  {'business_temp_closed': None, 'menu_url': 'ht...
# 3  {'business_temp_closed': None, 'menu_url': 'ht...
# 4  {'business_temp_closed': None, 'menu_url': 'ht...

# %%
## more data-specific way of summarizing
## we're doing a simple approach and just retaining
## cols that have a simple str structure
## if doing for real, would want to extract things
def clean_yelp_json(one_biz):

    ## restrict to str cols
    d_str = {key:value for key, value in one_biz.items()
             if type(value) == str}
    
    df_str = pd.DataFrame(d_str, index = [d_str['id']])
    return(df_str)

yelp_stronly = [clean_yelp_json(one_b) for one_b in yelp_genjson['businesses']]
yelp_stronly_df = pd.concat(yelp_stronly)

yelp_stronly_df.head(7)
# Out:
#                                             id  \
# 8ybF6YyRldtZmU9jil4xlg  8ybF6YyRldtZmU9jil4xlg
# XVGEEIH5rVB2QzW-qywcJw  XVGEEIH5rVB2QzW-qywcJw
# 5WW4g_LRwau29KyjZGLyAA  5WW4g_LRwau29KyjZGLyAA
# qxm3VNmD0O2zw8m9U8SxZg  qxm3VNmD0O2zw8m9U8SxZg
# KA8yhrd-ClVYMyOefXdVYg  KA8yhrd-ClVYMyOefXdVYg
# jAFLKiVXq9z_h4ZPy0nLMA  jAFLKiVXq9z_h4ZPy0nLMA
# vMyN7JL5cJExJORgIobbQg  vMyN7JL5cJExJORgIobbQg
#
#                                                      alias  \
# 8ybF6YyRldtZmU9jil4xlg   mollys-restaurant-and-bar-hanover
# XVGEEIH5rVB2QzW-qywcJw              base-camp-cafe-hanover
# 5WW4g_LRwau29KyjZGLyAA            sawtooth-kitchen-hanover
# qxm3VNmD0O2zw8m9U8SxZg                    duende-hanover-2
# KA8yhrd-ClVYMyOefXdVYg  lous-restaurant-and-bakery-hanover
# jAFLKiVXq9z_h4ZPy0nLMA              the-works-café-hanover
# vMyN7JL5cJExJORgIobbQg        tuk-tuk-thai-cuisine-hanover
#
#                                              name  \
# 8ybF6YyRldtZmU9jil4xlg   Molly's Restaurant & Bar
# XVGEEIH5rVB2QzW-qywcJw             Base Camp Cafe
# 5WW4g_LRwau29KyjZGLyAA           Sawtooth Kitchen
# qxm3VNmD0O2zw8m9U8SxZg                     Duende
# KA8yhrd-ClVYMyOefXdVYg  Lou's Restaurant & Bakery
# jAFLKiVXq9z_h4ZPy0nLMA             The Works Café
# vMyN7JL5cJExJORgIobbQg       Tuk Tuk Thai Cuisine
#
#                                                                 image_url  \
# 8ybF6YyRldtZmU9jil4xlg  https://s3-media4.fl.yelpcdn.com/bphoto/TJLrrA...
# XVGEEIH5rVB2QzW-qywcJw  https://s3-media1.fl.yelpcdn.com/bphoto/p8_YiE...
# 5WW4g_LRwau29KyjZGLyAA  https://s3-media3.fl.yelpcdn.com/bphoto/61MNG4...
# qxm3VNmD0O2zw8m9U8SxZg  https://s3-media4.fl.yelpcdn.com/bphoto/rf_h2D...
# KA8yhrd-ClVYMyOefXdVYg  https://s3-media3.fl.yelpcdn.com/bphoto/VAx8H9...
# jAFLKiVXq9z_h4ZPy0nLMA  https://s3-media2.fl.yelpcdn.com/bphoto/olpsy-...
# vMyN7JL5cJExJORgIobbQg  https://s3-media4.fl.yelpcdn.com/bphoto/--bUG3...
#
#                                                                       url  \
# 8ybF6YyRldtZmU9jil4xlg  https://www.yelp.com/biz/mollys-restaurant-and...
# XVGEEIH5rVB2QzW-qywcJw  https://www.yelp.com/biz/base-camp-cafe-hanove...
# 5WW4g_LRwau29KyjZGLyAA  https://www.yelp.com/biz/sawtooth-kitchen-hano...
# qxm3VNmD0O2zw8m9U8SxZg  https://www.yelp.com/biz/duende-hanover-2?adju...
# KA8yhrd-ClVYMyOefXdVYg  https://www.yelp.com/biz/lous-restaurant-and-b...
# jAFLKiVXq9z_h4ZPy0nLMA  https://www.yelp.com/biz/the-works-caf%C3%A9-h...
# vMyN7JL5cJExJORgIobbQg  https://www.yelp.com/biz/tuk-tuk-thai-cuisine-...
#
#                        price         phone   display_phone
# 8ybF6YyRldtZmU9jil4xlg    $$  +16036432570  (603) 643-2570
# XVGEEIH5rVB2QzW-qywcJw    $$  +16036432007  (603) 643-2007
# 5WW4g_LRwau29KyjZGLyAA   NaN  +16036435134  (603) 643-5134
# qxm3VNmD0O2zw8m9U8SxZg   NaN  +16033064826  (603) 306-4826
# KA8yhrd-ClVYMyOefXdVYg    $$  +16036433321  (603) 643-3321
# jAFLKiVXq9z_h4ZPy0nLMA   NaN  +16032772082  (603) 277-2082
# vMyN7JL5cJExJORgIobbQg    $$  +16032779192  (603) 277-9192

# %% [markdown]
# # Activity 2: pull restaurants in a different location
#
# - Try running a business search query for your hometown or another place by constructing a query similar to `yelp_genquery` but changing the location parameter
# - Other endpoints require feeding what's called the business' fusion id into the API. Take an id from `yelp_stronly.id` and use the documentation here to pull the reviews for that business: https://docs.developer.yelp.com/reference/v3_business_reviews
# - **Challenge**: generalize the previous step by writing a function that (1) takes a list of business ids as an input, (2) calls the reviews API for each id, (3) returns the results, and (4) rowbinds all results, i.e. turns them into a single, usable DataFrame

# %%
## use documentation to define what to search
## doc: https://www.yelp.com/developers/documentation/v3/business_search
## write the query 
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"
my_location = "Longview,TX,75605"
yelp_genquery = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location)

## use requests to call the API; here, we're
## passing it our credentials (structure varies
## by API and telling it to only return 10 results
## (max is 50 at once)
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp = requests.get(yelp_genquery, headers = header)
yelp_genresp

## then, look at structure of response
yelp_genjson = yelp_genresp.json()
# Out:
# <Response [200]>

# %%
## example business
yelp_genjson['businesses'][0]

## more automatic way of summarizing but things end up in lists
## within columns for things like categories
yelp_gendf = pd.DataFrame(yelp_genjson['businesses'])
yelp_gendf.head()
# Out:
# {'id': 'Hb_D_5nKTUkZdEfJnSxlDQ',
#  'alias': 'evergreen-food-factory-longview',
#  'name': 'Evergreen Food Factory',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5v6wWa7ZoIy1FYx2TXRC4Q/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/evergreen-food-factory-longview?adjust_creative=jmRDz3dQUAD9n2fAUWwDPQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=jmRDz3dQUAD9n2fAUWwDPQ',
#  'review_count': 47,
#  'categories': [{'alias': 'korean', 'title': 'Korean'},
#   {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#  'rating': 4.8,
#  'coordinates': {'latitude': 32.503674173777426,
#   'longitude': -94.76887542754412},
#  'transactions': ['pickup', 'delivery'],
#  'location': {'address1': '1402 W Marshall Ave',
#   'address2': '',
#   'address3': None,
#   'city': 'Longview',
#   'zip_code': '75604',
#   'country': 'US',
#   'state': 'TX',
#   'display_address': ['1402 W Marshall Ave', 'Longview, TX 75604']},
#  'phone': '+19034700342',
#  'display_phone': '(903) 470-0342',
#  'distance': 5080.546243747581,
#  'attributes': {'business_temp_closed': None,
#   'menu_url': None,
#   'open24_hours': None,
#   'waitlist_reservation': None}}
#                        id                            alias  \
# 0  Hb_D_5nKTUkZdEfJnSxlDQ  evergreen-food-factory-longview
# 1  wNfdtxP0rHof7xCyTq6Xkw               the-catch-longview
# 2  S2SOE4-QsjcyjQYMoPqJxA         scotties-bistro-longview
# 3  XkGy3rzvjLlQoCsqVSXElA          cafe-barrons-longview-4
# 4  U5NUHLeNI8z_fk-QM4OzUA               bubbas-33-longview
#
#                      name                                          image_url  \
# 0  Evergreen Food Factory  https://s3-media2.fl.yelpcdn.com/bphoto/5v6wWa...
# 1               The Catch  https://s3-media2.fl.yelpcdn.com/bphoto/5MRx-O...
# 2         Scotties Bistro  https://s3-media2.fl.yelpcdn.com/bphoto/WqTzAf...
# 3           Cafe Barron's  https://s3-media2.fl.yelpcdn.com/bphoto/jLMjkF...
# 4              Bubba's 33  https://s3-media1.fl.yelpcdn.com/bphoto/W2Zmos...
#
#    is_closed                                                url  review_count  \
# 0      False  https://www.yelp.com/biz/evergreen-food-factor...            47
# 1      False  https://www.yelp.com/biz/the-catch-longview?ad...           234
# 2      False  https://www.yelp.com/biz/scotties-bistro-longv...            51
# 3      False  https://www.yelp.com/biz/cafe-barrons-longview...            77
# 4      False  https://www.yelp.com/biz/bubbas-33-longview?ad...           162
#
#                                           categories  rating  \
# 0  [{'alias': 'korean', 'title': 'Korean'}, {'ali...     4.8
# 1  [{'alias': 'seafood', 'title': 'Seafood'}, {'a...     4.2
# 2  [{'alias': 'tradamerican', 'title': 'American'...     4.5
# 3  [{'alias': 'cafes', 'title': 'Cafes'}, {'alias...     3.9
# 4  [{'alias': 'burgers', 'title': 'Burgers'}, {'a...     3.9
#
#                                          coordinates        transactions  \
# 0  {'latitude': 32.503674173777426, 'longitude': ...  [pickup, delivery]
# 1  {'latitude': 32.5436941058377, 'longitude': -9...          [delivery]
# 2  {'latitude': 32.54532877788282, 'longitude': -...  [pickup, delivery]
# 3   {'latitude': 32.542082, 'longitude': -94.756265}          [delivery]
# 4  {'latitude': 32.541333466370475, 'longitude': ...          [delivery]
#
#                                             location         phone  \
# 0  {'address1': '1402 W Marshall Ave', 'address2'...  +19034700342
# 1  {'address1': '3312 N Fourth St', 'address2': '...  +19036632940
# 2  {'address1': '1188 E Hawkins Pkwy', 'address2'...  +14306257310
# 3  {'address1': '405 Loop 281 W', 'address2': '',...  +19036634737
# 4  {'address1': '200 E Loop 281', 'address2': '',...  +19032321606
#
#     display_phone     distance  \
# 0  (903) 470-0342  5080.546244
# 1  (903) 663-2940  1272.717812
# 2  (430) 625-7310  2676.395007
# 3  (903) 663-4737  1186.334123
# 4  (903) 232-1606   389.871743
#
#                                           attributes price
# 0  {'business_temp_closed': None, 'menu_url': Non...   NaN
# 1  {'business_temp_closed': None, 'menu_url': 'ht...    $$
# 2  {'business_temp_closed': None, 'menu_url': Non...   NaN
# 3  {'business_temp_closed': None, 'menu_url': Non...    $$
# 4  {'business_temp_closed': None, 'menu_url': 'ht...    $$

# %%
## more data-specific way of summarizing
## we're doing a simple approach and just retaining
## cols that have a simple str structure
## if doing for real, would want to extract things
def clean_yelp_json(one_biz):

    ## restrict to str cols
    d_str = {key:value for key, value in one_biz.items()
             if type(value) == str}
    
    df_str = pd.DataFrame(d_str, index = [d_str['id']])
    return(df_str)

yelp_stronly = [clean_yelp_json(one_b) for one_b in yelp_genjson['businesses']]
yelp_stronly_df = pd.concat(yelp_stronly)

yelp_stronly_df.head(15)
# Out:
#                                             id  \
# Hb_D_5nKTUkZdEfJnSxlDQ  Hb_D_5nKTUkZdEfJnSxlDQ
# wNfdtxP0rHof7xCyTq6Xkw  wNfdtxP0rHof7xCyTq6Xkw
# S2SOE4-QsjcyjQYMoPqJxA  S2SOE4-QsjcyjQYMoPqJxA
# XkGy3rzvjLlQoCsqVSXElA  XkGy3rzvjLlQoCsqVSXElA
# U5NUHLeNI8z_fk-QM4OzUA  U5NUHLeNI8z_fk-QM4OzUA
# GkH1EOkMRzmqWPNl4Z3UiA  GkH1EOkMRzmqWPNl4Z3UiA
# p5JddvSKOUm5N_RAnCSyOA  p5JddvSKOUm5N_RAnCSyOA
# xBOyUPWvPbE5Lhcdkymj8Q  xBOyUPWvPbE5Lhcdkymj8Q
# kTpmIYwolUve8hVCeYzO_A  kTpmIYwolUve8hVCeYzO_A
# Cci6YGrnTHyUv6uhMRBlDQ  Cci6YGrnTHyUv6uhMRBlDQ
# FRa6E8mIT2CospewEaHzlg  FRa6E8mIT2CospewEaHzlg
# ecEtK-cCh1UoYwX6Yb58TQ  ecEtK-cCh1UoYwX6Yb58TQ
# DQ0Qu7jP8JYJQbr0aTlByA  DQ0Qu7jP8JYJQbr0aTlByA
# EzcYLVOTPlrl_Vo-AyrXHg  EzcYLVOTPlrl_Vo-AyrXHg
# 9t7Kb-gRl4tM0ffcVld56A  9t7Kb-gRl4tM0ffcVld56A
#
#                                                                   alias  \
# Hb_D_5nKTUkZdEfJnSxlDQ                  evergreen-food-factory-longview
# wNfdtxP0rHof7xCyTq6Xkw                               the-catch-longview
# S2SOE4-QsjcyjQYMoPqJxA                         scotties-bistro-longview
# XkGy3rzvjLlQoCsqVSXElA                          cafe-barrons-longview-4
# U5NUHLeNI8z_fk-QM4OzUA                               bubbas-33-longview
# GkH1EOkMRzmqWPNl4Z3UiA                                 jaggers-longview
# p5JddvSKOUm5N_RAnCSyOA           nanny-goats-cafe-and-feed-bin-longview
# xBOyUPWvPbE5Lhcdkymj8Q                               mi-casita-longview
# kTpmIYwolUve8hVCeYzO_A                chiangmai-thai-kitchen-longview-3
# Cci6YGrnTHyUv6uhMRBlDQ            roost-chicken-salad-and-deli-longview
# FRa6E8mIT2CospewEaHzlg  kpot-korean-bbq-and-hot-pot-longview-longview-3
# ecEtK-cCh1UoYwX6Yb58TQ                             sushi-shima-longview
# DQ0Qu7jP8JYJQbr0aTlByA                         lovely-eatery-longview-2
# EzcYLVOTPlrl_Vo-AyrXHg                             don-benitos-longview
# 9t7Kb-gRl4tM0ffcVld56A                tia-juanitas-fish-camp-longview-2
#
#                                                name  \
# Hb_D_5nKTUkZdEfJnSxlDQ       Evergreen Food Factory
# wNfdtxP0rHof7xCyTq6Xkw                    The Catch
# S2SOE4-QsjcyjQYMoPqJxA              Scotties Bistro
# XkGy3rzvjLlQoCsqVSXElA                Cafe Barron's
# U5NUHLeNI8z_fk-QM4OzUA                   Bubba's 33
# GkH1EOkMRzmqWPNl4Z3UiA                      Jaggers
# p5JddvSKOUm5N_RAnCSyOA  Nanny Goats Cafe & Feed Bin
# xBOyUPWvPbE5Lhcdkymj8Q                    Mi Casita
# kTpmIYwolUve8hVCeYzO_A       Chiangmai Thai Kitchen
# Cci6YGrnTHyUv6uhMRBlDQ   Roost Chicken Salad & Deli
# FRa6E8mIT2CospewEaHzlg    KPOT Korean BBQ & Hot Pot
# ecEtK-cCh1UoYwX6Yb58TQ                  Sushi Shima
# DQ0Qu7jP8JYJQbr0aTlByA                Lovely Eatery
# EzcYLVOTPlrl_Vo-AyrXHg                 Don Benito's
# 9t7Kb-gRl4tM0ffcVld56A      Tia Juanita's Fish Camp
#
#                                                                 image_url  \
# Hb_D_5nKTUkZdEfJnSxlDQ  https://s3-media2.fl.yelpcdn.com/bphoto/5v6wWa...
# wNfdtxP0rHof7xCyTq6Xkw  https://s3-media2.fl.yelpcdn.com/bphoto/5MRx-O...
# S2SOE4-QsjcyjQYMoPqJxA  https://s3-media2.fl.yelpcdn.com/bphoto/WqTzAf...
# XkGy3rzvjLlQoCsqVSXElA  https://s3-media2.fl.yelpcdn.com/bphoto/jLMjkF...
# U5NUHLeNI8z_fk-QM4OzUA  https://s3-media1.fl.yelpcdn.com/bphoto/W2Zmos...
# GkH1EOkMRzmqWPNl4Z3UiA  https://s3-media1.fl.yelpcdn.com/bphoto/QOa2P8...
# p5JddvSKOUm5N_RAnCSyOA  https://s3-media1.fl.yelpcdn.com/bphoto/gTbA1A...
# xBOyUPWvPbE5Lhcdkymj8Q  https://s3-media2.fl.yelpcdn.com/bphoto/dbMsrA...
# kTpmIYwolUve8hVCeYzO_A  https://s3-media1.fl.yelpcdn.com/bphoto/TDA-uk...
# Cci6YGrnTHyUv6uhMRBlDQ  https://s3-media1.fl.yelpcdn.com/bphoto/FFpLU4...
# FRa6E8mIT2CospewEaHzlg  https://s3-media1.fl.yelpcdn.com/bphoto/LNGf0m...
# ecEtK-cCh1UoYwX6Yb58TQ  https://s3-media1.fl.yelpcdn.com/bphoto/l8MQKJ...
# DQ0Qu7jP8JYJQbr0aTlByA  https://s3-media1.fl.yelpcdn.com/bphoto/KHobyj...
# EzcYLVOTPlrl_Vo-AyrXHg  https://s3-media2.fl.yelpcdn.com/bphoto/NWCsdn...
# 9t7Kb-gRl4tM0ffcVld56A  https://s3-media1.fl.yelpcdn.com/bphoto/h5m3YE...
#
#                                                                       url  \
# Hb_D_5nKTUkZdEfJnSxlDQ  https://www.yelp.com/biz/evergreen-food-factor...
# wNfdtxP0rHof7xCyTq6Xkw  https://www.yelp.com/biz/the-catch-longview?ad...
# S2SOE4-QsjcyjQYMoPqJxA  https://www.yelp.com/biz/scotties-bistro-longv...
# XkGy3rzvjLlQoCsqVSXElA  https://www.yelp.com/biz/cafe-barrons-longview...
# U5NUHLeNI8z_fk-QM4OzUA  https://www.yelp.com/biz/bubbas-33-longview?ad...
# GkH1EOkMRzmqWPNl4Z3UiA  https://www.yelp.com/biz/jaggers-longview?adju...
# p5JddvSKOUm5N_RAnCSyOA  https://www.yelp.com/biz/nanny-goats-cafe-and-...
# xBOyUPWvPbE5Lhcdkymj8Q  https://www.yelp.com/biz/mi-casita-longview?ad...
# kTpmIYwolUve8hVCeYzO_A  https://www.yelp.com/biz/chiangmai-thai-kitche...
# Cci6YGrnTHyUv6uhMRBlDQ  https://www.yelp.com/biz/roost-chicken-salad-a...
# FRa6E8mIT2CospewEaHzlg  https://www.yelp.com/biz/kpot-korean-bbq-and-h...
# ecEtK-cCh1UoYwX6Yb58TQ  https://www.yelp.com/biz/sushi-shima-longview?...
# DQ0Qu7jP8JYJQbr0aTlByA  https://www.yelp.com/biz/lovely-eatery-longvie...
# EzcYLVOTPlrl_Vo-AyrXHg  https://www.yelp.com/biz/don-benitos-longview?...
# 9t7Kb-gRl4tM0ffcVld56A  https://www.yelp.com/biz/tia-juanitas-fish-cam...
#
#                                phone   display_phone price
# Hb_D_5nKTUkZdEfJnSxlDQ  +19034700342  (903) 470-0342   NaN
# wNfdtxP0rHof7xCyTq6Xkw  +19036632940  (903) 663-2940    $$
# S2SOE4-QsjcyjQYMoPqJxA  +14306257310  (430) 625-7310   NaN
# XkGy3rzvjLlQoCsqVSXElA  +19036634737  (903) 663-4737    $$
# U5NUHLeNI8z_fk-QM4OzUA  +19032321606  (903) 232-1606    $$
# GkH1EOkMRzmqWPNl4Z3UiA  +19035002774  (903) 500-2774   NaN
# p5JddvSKOUm5N_RAnCSyOA  +19036534801  (903) 653-4801    $$
# xBOyUPWvPbE5Lhcdkymj8Q  +19037588226  (903) 758-8226    $$
# kTpmIYwolUve8hVCeYzO_A  +19036636622  (903) 663-6622    $$
# Cci6YGrnTHyUv6uhMRBlDQ  +14306257373  (430) 625-7373   NaN
# FRa6E8mIT2CospewEaHzlg  +19033310792  (903) 331-0792   NaN
# ecEtK-cCh1UoYwX6Yb58TQ  +19032242221  (903) 224-2221   NaN
# DQ0Qu7jP8JYJQbr0aTlByA  +19033872973  (903) 387-2973   NaN
# EzcYLVOTPlrl_Vo-AyrXHg  +19032363491  (903) 236-3491   NaN
# 9t7Kb-gRl4tM0ffcVld56A                                 NaN

# %%
def get_business_reviews(business_ids):
    base_url = "https://api.yelp.com/v3/businesses/{}/reviews"
    header = {'Authorization': f"Bearer {API_KEY}"}
    total_reviews = []
    for bus_id in business_ids:
        total_query = base_url.format(bus_id)
        yelp_genresp = requests.get(total_query, headers = header)
        yelp_genresp
        yelp_genjson = yelp_genresp.json()['reviews']
        yelp_genjson
        for rev_dict in yelp_genjson:
            rev_dict["business_id"] = bus_id
        total_reviews += yelp_genjson
    final_df = pd.DataFrame(total_reviews)
    return final_df
get_business_reviews(["MRTdhLfHe-Uw-qQnQXxgVg", "PqyJx0ndtwBT9wLeFYnhoQ", "zeFASIGTjBwwPNf0ab86Jw"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[62], line 16
#      14     final_df = pd.DataFrame(total_reviews)
#      15     return final_df
# ---> 16 get_business_reviews(["MRTdhLfHe-Uw-qQnQXxgVg", "PqyJx0ndtwBT9wLeFYnhoQ", "zeFASIGTjBwwPNf0ab86Jw"])
#
# Cell In[62], line 9, in get_business_reviews(business_ids)
#       7 yelp_genresp = requests.get(total_query, headers = header)
#       8 yelp_genresp
# ----> 9 yelp_genjson = yelp_genresp.json()['reviews']
#      10 yelp_genjson
#      11 for rev_dict in yelp_genjson:
#
# KeyError: 'reviews'

# %%
yelp_strongly_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 yelp_strongly_df
#
# NameError: name 'yelp_strongly_df' is not defined

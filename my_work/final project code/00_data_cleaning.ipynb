# %% [markdown]
# ## Load Packages and Data

# %%
# Load Packages
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Load data from google drive
url = 'https://docs.google.com/spreadsheets/d/1Kz8fO-V7h5dwXl-hty1CNKybOttZnv3A/export?format=csv&gid=377439479'
df_demographics = pd.read_csv(url)

df_demographics.head()
# Out:
#    Local ID Date Enrolled in START  Status Status Date  \
# 0  11128335               7/1/2010  Active   7/22/2010
# 1  11134104              11/1/2011  Active  11/30/2011
# 2  11138520               5/1/2012  Active   5/21/2012
# 3  11132094               5/1/2013  Active    5/9/2013
# 4   975134C               7/1/2014  Active    7/1/2014
#
#                        Time Enrolled in START  \
# 0  Business Hours (Monday - Friday 8am - 5pm)
# 1  Business Hours (Monday - Friday 8am - 5pm)
# 2  Business Hours (Monday - Friday 8am - 5pm)
# 3  Business Hours (Monday - Friday 8am - 5pm)
# 4  Business Hours (Monday - Friday 8am - 5pm)
#
#         Source of referral to START Suitability of enrollment in START  \
# 0  Case Manager/Service Coordinator                        Appropriate
# 1  Case Manager/Service Coordinator                        Appropriate
# 2  Case Manager/Service Coordinator                        Appropriate
# 3  Case Manager/Service Coordinator                        Appropriate
# 4  Case Manager/Service Coordinator                        Appropriate
#
#   Individual/Caregiver reliable access to technology  \
# 0         Laptop/desktop, Tablet, Telephone landline
# 1  Cell phone service, High speed internet, Smart...
# 2    High speed internet, Tablet, Telephone landline
# 3  Cell phone service, High speed internet, Lapto...
# 4  High speed internet, Laptop/desktop, Smartphon...
#
#            Presenting problems at time of enrollment  \
# 0           Family needs assistance, Self-injurious
# 1  Aggression (physical, verbal, property destruc...
# 2  Diagnosis and treatment plan assistance, Famil...
# 3  Aggression (physical, verbal, property destruc...
# 4  Aggression (physical, verbal, property destruc...
#
#                               Services at Enrollment  ...  \
# 0  Behavioral support services, Case management/s...  ...
# 1  Behavioral support services, Case management/s...  ...
# 2  Case management/service coordination, Day serv...  ...
# 3  Behavioral support services, Case management/s...  ...
# 4  Case management/service coordination, Mental h...  ...
#
#   State sponsored ICF/DD stay in past 1 - 5 years (at enrollment to START)  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Jailed in the past year (at enrollment to START)  \
# 0                                               No
# 1                                               No
# 2                                               No
# 3                                               No
# 4                                               No
#
#   Jailed in the past 1 - 5 years (at enrollment to START)  \
# 0                                                 No
# 1                                                 No
# 2                                                 No
# 3                                                 No
# 4                                                 No
#
#   Employment Status at Enrollment Grade In School Current IEP  \
# 0          Day/vocational program             NaN          No
# 1                       Volunteer             NaN          No
# 2                    Not employed             NaN          No
# 3                 Employment (PT)             NaN          No
# 4                    Not employed             NaN          No
#
#   Current 504 Plan School Setting Custody Status Child Lives With
# 0               No            NaN            NaN              NaN
# 1               No            NaN            NaN              NaN
# 2               No            NaN            NaN              NaN
# 3               No            NaN            NaN              NaN
# 4               No            NaN            NaN              NaN
#
# [5 rows x 45 columns]

# %% [markdown]
# ## Individual/Caregiver Reliable Access to Technology Variable Cleaning

# %%
df_demographics['tech_access'] = df_demographics['Individual/Caregiver reliable access to technology']
df_demographics['tech_access']
# Out:
# 0              Laptop/desktop, Tablet, Telephone landline
# 1       Cell phone service, High speed internet, Smart...
# 2         High speed internet, Tablet, Telephone landline
# 3       Cell phone service, High speed internet, Lapto...
# 4       High speed internet, Laptop/desktop, Smartphon...
#                               ...
# 4981                                                  NaN
# 4982                                                  NaN
# 4983                                   Telephone landline
# 4984                                                  NaN
# 4985                                   Cell phone service
# Name: tech_access, Length: 4986, dtype: object

# %%
def clean_tech_access(entry):
    if isinstance(entry, str):  # Check if the entry is a string
        items = entry.split(',')
        items = [item.strip().lower() for item in items]
        items = sorted(set(items))  # Remove duplicates and sort
        return ', '.join(items)
    else:
        return entry  # Return the entry as is if it's not a string

# %%
df_demographics['tech_access'] = df_demographics['tech_access'].apply(clean_tech_access)
df_demographics['tech_access'] = df_demographics['tech_access'].fillna('none')
df_demographics['tech_access']
# Out:
# 0              laptop/desktop, tablet, telephone landline
# 1       cell phone service, high speed internet, smart...
# 2         high speed internet, tablet, telephone landline
# 3       cell phone service, high speed internet, lapto...
# 4       high speed internet, laptop/desktop, smartphon...
#                               ...
# 4981                                                 none
# 4982                                                 none
# 4983                                   telephone landline
# 4984                                                 none
# 4985                                   cell phone service
# Name: tech_access, Length: 4986, dtype: object

# %%
#df_demographics[df_demographics['tech_access'].str.contains('other')]
df_demographics.loc[df_demographics['tech_access'].str.contains('other'), 'tech_access']
# Out:
# 2564    other: has a cell phone but it does not work.,...
# 3784    cell phone service, other: individual prefers ...
# 4337    cell phone service, high speed internet, lapto...
# 4462    other: high internet risk - there is no wifi o...
# 4757    high speed internet, other: communication devi...
# 4918          cell phone service, other: zoom, smartphone
# 4974    cell phone service, high speed internet, lapto...
# Name: tech_access, dtype: object

# %%
# Clean the 'others'
# Define conditions and replacements
conditions = [
    df_demographics['tech_access'].str.contains("other: has a cell phone but it does not work", case=False),
    df_demographics['tech_access'].str.contains("cell phone service, other: individual prefers", case=False),
    df_demographics['tech_access'].str.contains("other: high internet risk - there is no wifi o", case=False),
    df_demographics['tech_access'].str.contains("high speed internet, other: communication devi", case=False),
    df_demographics['tech_access'].str.contains("cell phone service, other: zoom, smartphone", case=False),
    df_demographics['tech_access'].str.contains("cell phone service, high speed internet, laptop/desktop, other: computer", case=False),
    df_demographics['tech_access'].str.contains("cell phone service, high speed internet, laptop/desktop, other: individual", case=False)
]
replacements = [
    "telephone landline",
    "cell phone service, telephone landline",
    "none",
    "high speed internet, telephone landline",
    "cell phone service, smartphone",
    "cell phone service, high speed internet,laptop/desktop, smartphone, tablet",
    "cell phone service, high speed internet, laptop/desktop, telephone landline"
]

# Apply replacements based on conditions
df_demographics['tech_access'] = np.select(conditions, replacements, df_demographics['tech_access'])
df_demographics['tech_access']
# Out:
# 0              laptop/desktop, tablet, telephone landline
# 1       cell phone service, high speed internet, smart...
# 2         high speed internet, tablet, telephone landline
# 3       cell phone service, high speed internet, lapto...
# 4       high speed internet, laptop/desktop, smartphon...
#                               ...
# 4981                                                 none
# 4982                                                 none
# 4983                                   telephone landline
# 4984                                                 none
# 4985                                   cell phone service
# Name: tech_access, Length: 4986, dtype: object

# %%
df_demographics['num_categories'] = df_demographics['tech_access'].apply(lambda x: len(x.split(', ')))

# Calculate the average number of categories
average_num_categories = df_demographics['num_categories'].mean()

print("Average number of categories per entry:", average_num_categories) # maybe going forward in analysis we can make a dummy if people have 2 or more, etc
# Out:
# Average number of categories per entry: 1.4249899719213799

# %%
# One-Hot Encode the tech_access column
# dummies = df_demographics['tech_access'].str.get_dummies(sep=', ')

# Concatenate the one-hot encoded columns with the original DataFrame
# df_tech_access = pd.concat([df_demographics['Local ID'], dummies], axis=1)
# df_tech_access

# %% [markdown]
# ## Jail Variable Cleaning

# %%
df_demographics['jailed_prev_year'] = df_demographics['Jailed in the past year (at enrollment to START)']
df_demographics['jailed_prev_year']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#         ..
# 4981    No
# 4982    No
# 4983    No
# 4984    No
# 4985    No
# Name: jailed_prev_year, Length: 4986, dtype: object

# %%
df_demographics['jailed_prev_year'].value_counts()
# Out:
# jailed_prev_year
# No     4871
# Yes     115
# Name: count, dtype: int64

# %%
df_demographics['jailed_prev_five_years'] = df_demographics['Jailed in the past 1 - 5 years (at enrollment to START)']
df_demographics['jailed_prev_five_years']
# Out:
# 0       No
# 1       No
# 2       No
# 3       No
# 4       No
#         ..
# 4981    No
# 4982    No
# 4983    No
# 4984    No
# 4985    No
# Name: jailed_prev_five_years, Length: 4986, dtype: object

# %%
df_demographics['jailed_prev_five_years'].value_counts()
# Out:
# jailed_prev_five_years
# No     4857
# Yes     129
# Name: count, dtype: int64

# %%
def combine_jail_history(df):
    # Create a new variable indicating previous jail history
    df['jailed_prev'] = df.apply(lambda row: 'Yes' if row['jailed_prev_year'] == 'Yes' 
                                                    or row['jailed_prev_five_years'] == 'Yes'
                                               else 'No', axis=1)
    
    return df

# call func
combine_jail_history(df_demographics)
df_demographics
# Out:
#       Local ID Date Enrolled in START                         Status  \
# 0     11128335               7/1/2010                         Active
# 1     11134104              11/1/2011                         Active
# 2     11138520               5/1/2012                         Active
# 3     11132094               5/1/2013                         Active
# 4      975134C               7/1/2014                         Active
# ...        ...                    ...                            ...
# 4981     64995               8/1/2019             Inactive (other):
# 4982    366747               3/1/2019  Inactive (stable functioning)
# 4983     40366              10/1/2018  Inactive (stable functioning)
# 4984  11150993              11/1/2013                         Active
# 4985    250231              10/1/2020  Inactive (stable functioning)
#
#      Status Date                      Time Enrolled in START  \
# 0      7/22/2010  Business Hours (Monday - Friday 8am - 5pm)
# 1     11/30/2011  Business Hours (Monday - Friday 8am - 5pm)
# 2      5/21/2012  Business Hours (Monday - Friday 8am - 5pm)
# 3       5/9/2013  Business Hours (Monday - Friday 8am - 5pm)
# 4       7/1/2014  Business Hours (Monday - Friday 8am - 5pm)
# ...          ...                                         ...
# 4981  12/16/2021  Business Hours (Monday - Friday 8am - 5pm)
# 4982  12/16/2021  Business Hours (Monday - Friday 8am - 5pm)
# 4983  12/16/2021  Business Hours (Monday - Friday 8am - 5pm)
# 4984  12/16/2021  Business Hours (Monday - Friday 8am - 5pm)
# 4985  12/17/2021  Business Hours (Monday - Friday 8am - 5pm)
#
#                 Source of referral to START  \
# 0          Case Manager/Service Coordinator
# 1          Case Manager/Service Coordinator
# 2          Case Manager/Service Coordinator
# 3          Case Manager/Service Coordinator
# 4          Case Manager/Service Coordinator
# ...                                     ...
# 4981       Residential provider - community
# 4982       Case Manager/Service Coordinator
# 4983  Emergency services/mobile crisis team
# 4984       Case Manager/Service Coordinator
# 4985       Case Manager/Service Coordinator
#
#      Suitability of enrollment in START  \
# 0                           Appropriate
# 1                           Appropriate
# 2                           Appropriate
# 3                           Appropriate
# 4                           Appropriate
# ...                                 ...
# 4981                        Appropriate
# 4982                        Appropriate
# 4983                        Appropriate
# 4984                        Appropriate
# 4985                        Appropriate
#
#      Individual/Caregiver reliable access to technology  \
# 0            Laptop/desktop, Tablet, Telephone landline
# 1     Cell phone service, High speed internet, Smart...
# 2       High speed internet, Tablet, Telephone landline
# 3     Cell phone service, High speed internet, Lapto...
# 4     High speed internet, Laptop/desktop, Smartphon...
# ...                                                 ...
# 4981                                                NaN
# 4982                                                NaN
# 4983                                 Telephone landline
# 4984                                                NaN
# 4985                                 Cell phone service
#
#               Presenting problems at time of enrollment  \
# 0              Family needs assistance, Self-injurious
# 1     Aggression (physical, verbal, property destruc...
# 2     Diagnosis and treatment plan assistance, Famil...
# 3     Aggression (physical, verbal, property destruc...
# 4     Aggression (physical, verbal, property destruc...
# ...                                                 ...
# 4981  Aggression (physical, verbal, property destruc...
# 4982  Aggression (physical, verbal, property destruc...
# 4983  Aggression (physical, verbal, property destruc...
# 4984  Family needs assistance, Other: Team requestin...
# 4985  Decrease in ability to participate in daily fu...
#
#                                  Services at Enrollment  ...  \
# 0     Behavioral support services, Case management/s...  ...
# 1     Behavioral support services, Case management/s...  ...
# 2     Case management/service coordination, Day serv...  ...
# 3     Behavioral support services, Case management/s...  ...
# 4     Case management/service coordination, Mental h...  ...
# ...                                                 ...  ...
# 4981  Behavioral support services, Case management/s...  ...
# 4982  Behavioral support services, Case management/s...  ...
# 4983  Case management/service coordination, Day serv...  ...
# 4984  Case management/service coordination, Day serv...  ...
# 4985  Case management/service coordination, Respite ...  ...
#
#      Employment Status at Enrollment Grade In School Current IEP  \
# 0             Day/vocational program             NaN          No
# 1                          Volunteer             NaN          No
# 2                       Not employed             NaN          No
# 3                    Employment (PT)             NaN          No
# 4                       Not employed             NaN          No
# ...                              ...             ...         ...
# 4981          Day/vocational program       Graduated          No
# 4982          Day/vocational program             NaN         NaN
# 4983          Day/vocational program             NaN          No
# 4984          Day/vocational program             NaN          No
# 4985                    Not employed             NaN         NaN
#
#      Current 504 Plan School Setting    Custody Status   Child Lives With  \
# 0                  No            NaN               NaN                NaN
# 1                  No            NaN               NaN                NaN
# 2                  No            NaN               NaN                NaN
# 3                  No            NaN               NaN                NaN
# 4                  No            NaN               NaN                NaN
# ...               ...            ...               ...                ...
# 4981               No            NaN  Parental custody  Residential staff
# 4982              NaN            NaN               NaN                NaN
# 4983               No            NaN               NaN                NaN
# 4984               No            NaN               NaN                NaN
# 4985              NaN            NaN               NaN                NaN
#
#      jailed_prev_year jailed_prev_five_years jailed_prev
# 0                  No                     No          No
# 1                  No                     No          No
# 2                  No                     No          No
# 3                  No                     No          No
# 4                  No                     No          No
# ...               ...                    ...         ...
# 4981               No                     No          No
# 4982               No                     No          No
# 4983               No                     No          No
# 4984               No                     No          No
# 4985               No                     No          No
#
# [4986 rows x 48 columns]

# %%
df_demographics['jailed_prev'].value_counts()
# Out:
# jailed_prev
# No     4796
# Yes     190
# Name: count, dtype: int64

# %%
df_demographics["Who is the individual's primary caregiver?"].value_counts()
# Out:
# Who is the individual's primary caregiver?
# Parent                       2707
# Paid support staff           1292
# Self                          285
# Other family member           237
# Guardian                      215
# Authorized representative     121
# Name: count, dtype: int64

# %%
df_demographics['Ethnicity'].value_counts()
# Out:
# Ethnicity
# Not of Hispanic origin                      3798
# Hispanic - specific origin not specified     777
# Unknown, not collected                       411
# Name: count, dtype: int64

# %%
# new labels
replacements = {
    'Not of Hispanic origin': 'Not Hispanic Descent',
    'Hispanic - specific origin not specified': 'Hispanic Descent',
    'Unknown, not collected': 'Unknown'
}

# replace the values in ethnicity
df_demographics['Ethnicity'] = df_demographics['Ethnicity'].replace(replacements)


df_demographics['Ethnicity'].value_counts()
# Out:
# Ethnicity
# Not Hispanic Descent    3798
# Hispanic Descent         777
# Unknown                  411
# Name: count, dtype: int64

# %%
# filter out unknowns
df_demographics['ethnicity_binary'] = df_demographics['Ethnicity'].apply(lambda x: x if x != 'Unknown' else None)
df_demographics['ethnicity_binary'].value_counts()
# Out:
# ethnicity_binary
# Not Hispanic Descent    3798
# Hispanic Descent         777
# Name: count, dtype: int64
